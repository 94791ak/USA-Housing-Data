# %% [markdown]
# ## EDA AND FEATURE ENGINEERING

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_final = pd.read_csv("DATA.csv")
df_final = df_final.drop("DATE", axis=1)
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   all_Const_Emp         241 non-null    float64
#  1   emratio               241 non-null    float64
#  2   GDP                   241 non-null    float64
#  3   home_ow_rate          241 non-null    float64
#  4   house_st              241 non-null    int64
#  5   income                241 non-null    float64
#  6   IPI_Cement            241 non-null    float64
#  7   labor_percent         241 non-null    float64
#  8   monthly_supply        241 non-null    float64
#  9   MSPUS                 241 non-null    int64
#  10  new_private_house     241 non-null    int64
#  11  new_private_hw_under  241 non-null    int64
#  12  p_saving_rate         241 non-null    float64
#  13  permit                241 non-null    int64
#  14  population            241 non-null    int64
#  15  PPI_Cement            241 non-null    float64
#  16  PPI_Concrete          241 non-null    float64
#  17  target                241 non-null    float64
#  18  total_emp_cons        241 non-null    int64
#  19  unemployed_rate       241 non-null    float64
#  20  mortgage_rate         241 non-null    float64
# dtypes: float64(14), int64(7)
# memory usage: 39.7 KB

# %%
df_final.describe()
# Out:
#        all_Const_Emp     emratio           GDP  home_ow_rate     house_st  \
# count     241.000000  241.000000    241.000000    241.000000   241.000000
# mean      779.371369   60.075104  18097.262676     66.078008  1227.535270
# std       139.865434    1.885306   4203.980426      1.775473   439.623996
# min       556.900000   51.200000  11923.447000     63.100000   478.000000
# 25%       650.500000   58.700000  14706.538000     64.700000   917.000000
# 50%       800.300000   59.900000  17197.738000     65.700000  1206.000000
# 75%       910.400000   61.100000  20917.867000     67.500000  1520.000000
# max      1022.000000   63.400000  28269.174000     69.400000  2273.000000
#
#              income  IPI_Cement  labor_percent  monthly_supply          MSPUS  \
# count    241.000000  241.000000     241.000000      241.000000     241.000000
# mean   15367.713693  111.268488      63.838174        6.345643  289071.369295
# std     3830.339043   27.515660       1.555754        1.922214   66388.593161
# min     9731.800000   66.364600      60.100000        3.300000  208400.000000
# 25%    12227.800000   95.916800      62.700000        5.000000  233900.000000
# 50%    14456.400000  101.787200      63.300000        5.700000  275200.000000
# 75%    18053.900000  118.448000      65.800000        7.600000  322800.000000
# max    24471.800000  192.005800      66.400000       12.200000  442600.000000
#
#        ...  new_private_hw_under  p_saving_rate       permit     population  \
# count  ...            241.000000     241.000000   241.000000     241.000000
# mean   ...           1035.912863       5.877593  1292.248963  317126.639004
# std    ...            370.771601       3.552921   463.359360   13246.504152
# min    ...            414.000000       1.400000   513.000000  292046.000000
# 25%    ...            726.000000       4.100000   980.000000  306035.000000
# 50%    ...           1100.000000       5.500000  1273.000000  318464.000000
# 75%    ...           1268.000000       6.400000  1598.000000  329766.000000
# max    ...           1711.000000      32.000000  2263.000000  336194.000000
#
#        PPI_Cement  PPI_Concrete      target  total_emp_cons  unemployed_rate  \
# count  241.000000    241.000000  241.000000      241.000000       241.000000
# mean   224.052465    219.883066  189.752154     6851.058091         5.882988
# std     42.557324     46.654761   48.577546      798.137606         2.102598
# min    149.400000    154.400000  133.996000     5427.000000         3.400000
# 25%    194.600000    196.000000  153.815000     6109.000000         4.400000
# 50%    209.100000    207.000000  176.597000     7044.000000         5.100000
# 75%    251.200000    250.600000  205.362000     7523.000000         7.300000
# max    345.633000    351.033000  312.747000     8146.000000        14.800000
#
#        mortgage_rate
# count     241.000000
# mean        4.723112
# std         1.186151
# min         2.650000
# 25%         3.800000
# 50%         4.460000
# 75%         5.810000
# max         7.760000
#
# [8 rows x 21 columns]

# %% [markdown]
# ### Plotting density plot for all the numerical features

# %%
plt.figure(figsize=(12, 6))
for col in df_final.columns.tolist():
    plt.figure(figsize=(6, 4))
    sns.displot(data=df_final, x=col, kde =True)
    plt.xlabel(f"{col}")
    plt.ylabel("Count")
    plt.title(f'Distribution Plot for {col}')
    plt.show()

# %% [markdown]
# ### Plotting boxplot for analyzing the outliers in the data

# %%
plt.figure(figsize=(12, 6))
for col in df_final.columns.tolist():
    plt.figure(figsize=(6, 4))
    sns.boxplot(data=df_final, x=col)
    plt.xlabel(f"{col}")
    plt.title(f'Box Plot for {col}')
    plt.show()

# %% [markdown]
# **We have outliers in few features:**
#
# - p_saving_rate
# - PPI_Concrete
# - new_private_house
# - emratio
# - new_private_hw_under
# - monthly_supply
# - unemployed_rate

# %% [markdown]
# ### Treating Skewness and Outliers:

# %% [markdown]
# #### p_saving_rate

# %%
df_final['p_saving_rate'].skew()
# Out:
# 3.5705322512539697

# %% [markdown]
# - Personal saving rate column is highly right skewed. Hence we will apply IQR method for handling outliers.

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["p_saving_rate"].quantile(0.25)
q2 = df_final["p_saving_rate"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 0.6499999999999986
# 9.850000000000001
# (None, None)

# %%
# capping the features to upper boundry only.
df_final.loc[df_final['p_saving_rate'] >=upper_bridge,'p_saving_rate'] = upper_bridge

# %%
df_final['p_saving_rate'].hist()
plt.title("Distribution of Personal Saving rate after handling outliers")
plt.xlabel("p_saving_rate")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### PPI_Concrete

# %%
df_final['PPI_Concrete'].skew()
# Out:
# 0.9837942582229477

# %% [markdown]
# - Producer price index of concrete column is highly right skewed. Hence we will apply Log transformation for handling skewness first.

# %%
df_final['PPI_Concrete'] = np.log1p(df_final['PPI_Concrete'])

# %%
df_final['PPI_Concrete'].hist()
# Out:
# <Axes: >

# %%
plt.boxplot(df_final['PPI_Concrete'], vert=False)
plt.xlabel('PPI_Concrete')
plt.title('Box Plot of PPI_Concrete')
plt.show()

# %% [markdown]
# - Skewness and outliers both removed by using log transformation.

# %% [markdown]
# #### new_private_house

# %%
df_final['new_private_house'].skew()
# Out:
# 0.39508390648058195

# %% [markdown]
# - New private house completely constructed units- column is negatively skewed and having outliers in the maximum side. We are going to apply yeo-johnson transformation for removing skewness.

# %%
from scipy import stats

transformed_data, lambda_value = stats.yeojohnson(df_final['new_private_house'])
df_final['new_private_house'] = transformed_data

# %%
plt.boxplot(df_final['new_private_house'], vert=False)
plt.xlabel('new_private_house')
plt.title('Box Plot of new_private_house')
plt.show()

# %%
max_value = df_final['new_private_house'].max()

df_final['new_private_house'] = np.where(df_final['new_private_house'] > max_value, max_value, df_final['new_private_house'])

# %% [markdown]
# #### emratio

# %%
df_final['emratio'].skew()
# Out:
# -0.43518125693893417

# %% [markdown]
# - Employment population ratio column is negatively skewed and having outliers in the minimum side. We are going to apply IQR method for handling outliers.

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["emratio"].quantile(0.25)
q2 = df_final["emratio"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 55.10000000000001
# 64.7
# (None, None)

# %%
df_final.loc[df_final['emratio'] <=lower_bridge,'emratio'] = lower_bridge

# %%
plt.boxplot(df_final['emratio'], vert=False)
plt.xlabel('emratio')
plt.title('Box Plot of emratio')
plt.show()

# %% [markdown]
# #### new_private_hw_under

# %%
df_final['new_private_hw_under'].skew()
# Out:
# -0.06784207698605721

# %% [markdown]
# - New private house units under contruction column is right skewed. We will apply IQR Method to deal with the outliers.

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["new_private_hw_under"].quantile(0.25)
q2 = df_final["new_private_hw_under"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# -87.0
# 2081.0
# (None, None)

# %%
df_final.loc[df_final['new_private_hw_under'] >=upper_bridge,'new_private_hw_under'] = upper_bridge

# %%
plt.boxplot(df_final['new_private_hw_under'], vert=False)
plt.xlabel('new_private_hw_under')
plt.title('Box Plot of new_private_hw_under')
plt.show()

# %% [markdown]
# #### Monthly_supply

# %%
df_final['monthly_supply'].skew()
# Out:
# 0.8889263841166541

# %% [markdown]
# - Monthly supply of houses column is right skewed. We will apply IQR Method to deal with the outliers.

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["monthly_supply"].quantile(0.25)
q2 = df_final["monthly_supply"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 1.1000000000000005
# 11.5
# (None, None)

# %%
df_final.loc[df_final['monthly_supply'] >=upper_bridge,'monthly_supply'] = upper_bridge

# %%
df_final['monthly_supply'].hist()
# Out:
# <Axes: >

# %% [markdown]
# #### unemployed_rate

# %%
df_final['unemployed_rate'].skew()
# Out:
# 1.0530868834848872

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["unemployed_rate"].quantile(0.25)
q2 = df_final["unemployed_rate"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 0.05000000000000071
# 11.649999999999999
# (None, None)

# %%
df_final.loc[df_final['unemployed_rate'] >=upper_bridge,'unemployed_rate'] = upper_bridge

# %%
plt.boxplot(df_final['unemployed_rate'], vert=False)
plt.xlabel('unemployed_rate')
plt.title('Box Plot of unemployed_rate')
plt.show()

# %% [markdown]
# ### Understanding the Correlations between the data

# %%
corr_matrix= df_final.corr()
corr_matrix['target'].sort_values(ascending=False)
# Out:
# target                  1.000000
# MSPUS                   0.939120
# PPI_Cement              0.920266
# GDP                     0.892063
# income                  0.872675
# PPI_Concrete            0.853962
# new_private_hw_under    0.823337
# total_emp_cons          0.738315
# population              0.689177
# all_Const_Emp           0.572717
# permit                  0.465694
# new_private_house       0.441251
# house_st                0.430164
# monthly_supply          0.161172
# mortgage_rate           0.070021
# p_saving_rate          -0.006687
# emratio                -0.024929
# IPI_Cement             -0.134632
# home_ow_rate           -0.176987
# labor_percent          -0.547616
# unemployed_rate        -0.584157
# Name: target, dtype: float64

# %% [markdown]
# ### Checking Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data = pd.DataFrame()
vif_data["feature"] = df_final.columns

vif_data["VIF"] = [variance_inflation_factor(df_final.values, i)
                          for i in range(len(df_final.columns))]

print(vif_data)
# Out:
#                  feature            VIF
# 0          all_Const_Emp    9326.310648
# 1                emratio  271877.882891
# 2                    GDP    8601.533749
# 3           home_ow_rate   62885.947456
# 4               house_st     419.901521
# 5                 income    2828.181085
# 6             IPI_Cement     312.663265
# 7          labor_percent  228841.528104
# 8         monthly_supply     113.926113
# 9                  MSPUS    2512.693228
# 10     new_private_house    2426.205842
# 11  new_private_hw_under    1009.402615
# 12         p_saving_rate      57.070283
# 13                permit     548.720811
# 14            population   44358.710451
# 15            PPI_Cement    3814.476906
# 16          PPI_Concrete   84377.848180
# 17                target    4239.785003
# 18        total_emp_cons   16000.436225
# 19       unemployed_rate    1726.269716
# 20         mortgage_rate     162.326743

# %% [markdown]
# We have high multicollinearity in our data. Need to handle this before fedding into the model

# %%
df_final.to_csv("df_final.csv")
